# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from quotes.models import ChadhNovel, Alignment

def plot_chadh_histogram(novel):
    
    alignments = (
        Alignment.query
        .filter(
            Alignment.a_id==novel.id,
            Alignment.size >= 5
        )
    )
    
    quoted = []
    for a in alignments:
        quoted += range(a.a_start, a.a_start + a.size)

    
    text = Text(novel.text)
    
    plt.figure(figsize=(20, 5))

    n, bins, patches = plt.hist(
        quoted,
        range=(0, len(text.tokens)),
        bins=500,
        color='green',
    )

    print(novel.slug)
    plt.show()

# %%
from quotes.text import Text

for novel in ChadhNovel.query.all():
    plot_chadh_histogram(novel)
# Out:
# Chadwyck_British_1782_Burney_CeciliaorMemoirs
# Chadwyck_British_1786_Beckford_VathekTranslatedfrom
# Chadwyck_British_1788_Shelley_MaryAFiction
# Chadwyck_British_1788_Smith_EmmelinetheOrphan
# Chadwyck_British_1790_Radcliffe_ASicilianRomance
# Chadwyck_British_1791_Inchbald_ASimpleStory
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-764a4be47cbf> in <module>()
#       2
#       3 for novel in ChadhNovel.query.all():
# ----> 4     plot_chadh_histogram(novel)
#
# <ipython-input-13-ee19dd423418> in plot_chadh_histogram(novel)
#      12
#      13     quoted = []
# ---> 14     for a in alignments:
#      15         quoted += range(a.a_start, a.a_start + a.size)
#      16
#
# /Users/dclure/Projects/quotes/env/lib/python3.5/site-packages/sqlalchemy/orm/loading.py in instances(query, cursor, context)
#      69                     break
#      70             else:
# ---> 71                 fetch = cursor.fetchall()
#      72
#      73             if single_entity:
#
# /Users/dclure/Projects/quotes/env/lib/python3.5/site-packages/sqlalchemy/engine/result.py in fetchall(self)
#    1124             self.connection._handle_dbapi_exception(
#    1125                 e, None, None,
# -> 1126                 self.cursor, self.context)
#    1127
#    1128     def fetchmany(self, size=None):
#
# /Users/dclure/Projects/quotes/env/lib/python3.5/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1394                 )
#    1395             else:
# -> 1396                 util.reraise(*exc_info)
#    1397
#    1398         finally:
#
# /Users/dclure/Projects/quotes/env/lib/python3.5/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     184         if value.__traceback__ is not tb:
#     185             raise value.with_traceback(tb)
# --> 186         raise value
#     187
#     188 else:
#
# /Users/dclure/Projects/quotes/env/lib/python3.5/site-packages/sqlalchemy/engine/result.py in fetchall(self)
#    1118
#    1119         try:
# -> 1120             l = self.process_rows(self._fetchall_impl())
#    1121             self._soft_close()
#    1122             return l
#
# /Users/dclure/Projects/quotes/env/lib/python3.5/site-packages/sqlalchemy/engine/result.py in _fetchall_impl(self)
#    1069     def _fetchall_impl(self):
#    1070         try:
# -> 1071             return self.cursor.fetchall()
#    1072         except AttributeError:
#    1073             return self._non_result([])
#
# KeyboardInterrupt:
